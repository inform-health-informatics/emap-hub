# %%
# Database management
import sqlalchemy as sa
import psycopg2

# Data wrangling
import pandas as pd
import numpy as np
import requests
import json
from datetime import datetime, timedelta



# Data visualisation
import matplotlib.pylab as plt
# %matplotlib inline
import seaborn
seaborn.set()

# utilities
import pprint as pp

# %%
# load up database scripts and connect to db
conn_eops = {'user': 'uds_read',
            'host': 'UCLVLDDDTAEPS02',
            'port': 5432,
            'password': 'klq;wed-0i439^^%',
            'database': 'uds'      
            }

def gen_connection_string(d, engine='postgresql'):
    """Generates a SQLAlchemy connection string from a dictionary"""
    # e.g. # engine = create_engine('postgresql+psycopg2://steve@localhost:5432/omop')
    # TODO @later permit other interfaces
    d['port'] = str(d['port'])

    if engine == 'postgresql':
        if d.get('password'):
            return 'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}'.format(**d)
        else:
            return 'postgresql+psycopg2://{user}@{host}:{port}/{database}'.format(**d)

    elif engine == 'psycopg2':
        if d.get('password'):
            return 'host={host} dbname={database} user={user} password={password} port={port}'.format(**d)
        else:
            return 'host={host} dbname={database} user={user} port={port}'.format(**d)

# %%
URL = gen_connection_string(conn_eops, engine='postgresql')
DSN = gen_connection_string(conn_eops, engine='psycopg2')
conn = psycopg2.connect(DSN, options=f'-c search_path=live')

# %%
engine = sa.create_engine(URL, connect_args= {'options': '-c search_path=live'})
inspector = sa.inspect(engine)
print(inspector.get_table_names())
# Out:
# ['ids_progress', 'tbl_ids_master', 'person', 'person_mrn', 'ids_effect_logging', 'mrn_encounter', 'patient_fact', 'encounter', 'patient_property', 'attribute', 'mrn']

# %%
metadata = sa.MetaData()
metadata.reflect(bind=engine)
ttables = metadata.sorted_tables
ttables = {t.name:t.columns.keys() for t in ttables}
ttables.keys()
# Out:
# dict_keys(['attribute', 'encounter', 'ids_effect_logging', 'ids_progress', 'mrn', 'person', 'tbl_ids_master', 'mrn_encounter', 'patient_fact', 'person_mrn', 'patient_property'])

# %%
# let's inspect the columns
pd.read_sql('attribute', engine)
# Out:
#     attribute_id                added_time  \
# 0              1 2019-03-04 17:00:00+00:00
# 1              2 2019-03-04 17:00:00+00:00
# 2              3 2019-03-04 17:00:00+00:00
# 3              4 2019-03-04 17:00:00+00:00
# 4              5 2019-03-05 11:33:00+00:00
# 5              6 2019-03-19 16:40:00+00:00
# 6              7 2019-03-05 11:33:00+00:00
# 7              8 2019-03-05 11:33:00+00:00
# 8              9 2019-03-19 16:40:00+00:00
# 9             10 2019-03-20 11:56:00+00:00
# 10            11 2019-04-11 10:00:00+00:00
# 11            12 2019-04-11 10:00:00+00:00
# 12            13 2019-04-11 10:00:00+00:00
# 13            14 2019-04-11 10:00:00+00:00
# 14            15 2019-04-11 10:00:00+00:00
# 15            16 2019-04-11 10:00:00+00:00
# 16            17 2019-04-11 10:00:00+00:00
# 17            18 2019-04-11 10:00:00+00:00
# 18            19 2019-04-11 10:00:00+00:00
# 19            20 2019-06-20 16:00:00+00:00
# 20            21 2019-06-20 16:00:00+00:00
# 21            22 2019-06-20 16:00:00+00:00
# 22            23 2019-06-20 16:00:00+00:00
# 23            24 2019-06-20 16:00:00+00:00
# 24            25 2019-06-20 16:00:00+00:00
# 25            26 2019-06-20 16:00:00+00:00
# 26            27 2019-06-20 16:00:00+00:00
# 27            28 2019-07-13 17:00:00+00:00
# 28            29 2019-07-13 17:00:00+00:00
# 29            30 2019-07-13 17:00:00+00:00
# 30            31 2019-07-23 15:00:00+00:00
# 31            32 2019-07-23 15:00:00+00:00
# 32            33 2019-07-23 15:00:00+00:00
# 33            34 2019-07-25 18:00:00+00:00
# 34            35 2019-07-25 18:00:00+00:00
# 35            36 2019-07-31 17:00:00+00:00
# 36            37 2019-07-31 17:00:00+00:00
# 37            38 2019-07-31 17:00:00+00:00
# 38            39 2019-07-31 17:00:00+00:00
# 39            40 2019-08-15 17:00:00+00:00
#
#                                           description  result_type  \
# 0                                          First name            1
# 1                   Middles names separated by spaces            1
# 2                                         Family name            1
# 3                     Fact group containing name data            0
# 4                   Fact group about a hospital visit            0
# 5                        Fact group about a bed visit            0
# 6                                     Time of arrival            2
# 7                                   Time of departure            2
# 8                                            Location            1
# 9                                        Parent visit            3
# 10  General Demographics that are single key value...            0
# 11                                      Date of Birth            2
# 12                                                Sex            4
# 13                                               Male            0
# 14                                             Female            0
# 15                                              Other            0
# 16                                            Unknown            0
# 17                                           Postcode            1
# 18                                         NHS number            1
# 19                                          Fact type            0
# 20                Local code for the battery of tests            1
# 21         Local description for the battery of tests            1
# 22                Local code for the single test item            1
# 23         Local description for the single test item            1
# 24        Coding system (aka vocab) for the test code            1
# 25                   Pathology result numerical value            5
# 26             Pathology result numerical value units            1
# 27                     Reference range for the result            1
# 28                   When the result was last updated            2
# 29               The status of the result (final etc)            1
# 30                          Pathology order fact type            0
# 31                         Pathology order control ID            1
# 32                        Pathology Epic order number            1
# 33  Pathology order lab/specimen number aka access...            1
# 34  Pathology order lab/specimen number with extra...            1
# 35                 Sample collection/observation time            2
# 36                 When the order was originally made            2
# 37  The type of the patient that the order relates to            1
# 38        Time of last change of status for the order            2
# 39                          Local code of the isolate            1
#
#          short_name
# 0            F_NAME
# 1            M_NAME
# 2            L_NAME
# 3            NAMING
# 4        HOSP_VISIT
# 5         BED_VISIT
# 6      ARRIVAL_TIME
# 7        DISCH_TIME
# 8          LOCATION
# 9       VISIT_PAREN
# 10     GENERAL_DEMO
# 11              DOB
# 12              SEX
# 13             MALE
# 14           FEMALE
# 15            OTHER
# 16          UNKNOWN
# 17        POST_CODE
# 18       NHS_NUMBER
# 19      PATH_RESULT
# 20    PATH_BATT_COD
# 21   PATH_BATT_DESC
# 22    PATH_TEST_COD
# 23   PATH_TEST_DESC
# 24     PATH_COD_SYS
# 25   PATH_NUM_VALUE
# 26   PATH_NUM_UNITS
# 27   PATH_REF_RANGE
# 28    PATH_RES_TIME
# 29     PATH_RES_STS
# 30       PATH_ORDER
# 31  PATH_ORD_CTL_ID
# 32    PATH_EPIC_NUM
# 33     PATH_LAB_NUM
# 34     PATH_OCS_NUM
# 35   PATH_COLL_TIME
# 36  PATH_ORDER_TIME
# 37  PATH_ORDER_TYPE
# 38    PATH_STS_TIME
# 39   PATH_ISOL_CODE

# %%
pds = pd.read_sql(
    """select distinct on (pp1.value_as_string) 
        pp1.value_as_string, 
        pp2.value_as_string,
        pp1.parent_fact 
     from patient_property pp1 
     left join patient_property pp2 
        on pp1.parent_fact = pp2.parent_fact 
        where pp2.attribute=24 
        or
        pp1.attribute = 23;
    """
    , engine)
pds
# Out:
#      value_as_string value_as_string  parent_fact
# 0               1433               F     98973442
# 1                1AD               F     53806148
# 2               1CAM               F     96397747
# 3                1EG               F     63468074
# 4                1HD               F     51929671
# ...              ...             ...          ...
# 2073            ZINC               F     99389554
# 2074             ZNS               F     99136548
# 2075            ZNSD               F     99136566
# 2076            ZNST               F     99136557
# 2077            ZNT8               F     87820102
#
# [2078 rows x 3 columns]

# %%
res = pd.concat([pds, pds.value_as_string.str.split('\\^', expand=True)], axis=1)
res
# Out:
#                   value_as_string         0               1          2
# 0     GWNC^CHALF WGC SR21^SR21-21      GWNC  CHALF WGC SR21    SR21-21
# 1         RBNQ^Q3NRU WAITING^WAIT      RBNQ   Q3NRU WAITING       WAIT
# 2          T12S^T12S BY04^BY04-27      T12S       T12S BY04    BY04-27
# 3           T01^T01 BY04^BY04-53B       T01        T01 BY04   BY04-53B
# 4          MVNQ^Q6MV BY03^BY03-06      MVNQ       Q6MV BY03    BY03-06
# ...                           ...       ...             ...        ...
# 1832  MCUN^E03MCUN BY05^BY05-C15B      MCUN    E03MCUN BY05  BY05-C15B
# 1833        HASU^T07 BY05^BY05-24      HASU        T07 BY05    BY05-24
# 1834      MFNQ^C4MLF BY02^BY02-05      MFNQ      C4MLF BY02    BY02-05
# 1835        T01^T01 BY04^BY04-49B       T01        T01 BY04   BY04-49B
# 1836   EDHRSURG^ED REST WAIT^WAIT  EDHRSURG    ED REST WAIT       WAIT
#
# [1837 rows x 4 columns]

# %%
res.sort_values(by=0).to_csv('extract_locations.csv')
